# %% [markdown]
# # Shreya  Lab 5/6

# %% [markdown]
# <font size="4">**What information do you have?**</font>

# %% [markdown]
# In our surevy we asked aboout the previous and future living situationns of UCR students before and after the pandemic. We asked for:
# <br>~ where they lived BEFORE covid (On campus apartment, Off campus apartment, Greek House, UCR Dorms)
# <br>~ where they want to live AFTER covid (On campus apartment, Off campus apartment, Greek House, UCR Dorms)
# <br>~ where they would liive if finances were not a burden (on campus/ off campus)
# <br>~ whether they prefer in person, remote learning or both

# %% [markdown]
# <font size="4">**What would you like to know about the class?**</font>

# %% [markdown]
# We would like to know if there was a shift in preferences on housing before and after the pandemic. Due to the pandemic many people had to leave and we wanted to know if their experiences during that time of leaving and being away has affected their thought on where they want to stay. When campus closed last march many student had to leave and almost all students living on campus recieved a refund for the portion of payment left in the remaining year however off campus students were not so lucky. We also want to know if more students would live on campus/off campus if finances were not an issue and how that aligns with where students are actually living. Furthermore, we want to see if there is a correlation between where students live and their gender such as are female student more likely to live closer to campus? We also want to know if people's preferences on learning will determine where they live.

# %% [markdown]
# <font size="4">**Explore the data.**</font>

# %%
import pandas as pd
df = pd.read_csv("Responses Clean.csv")
df.head()
df["Housing BC"] = df["Housing BC"].str.replace('with parents', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('With parents', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('off-campus, Parents house', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('at home', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('home', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('I lived parents', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('Off-campus parents', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('I lived resident', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('I lived Resident', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace('Local Resident prior', 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace("Crashed at friends' couches", 'Resident')
df["Housing BC"] = df["Housing BC"].str.replace("Same Resident", 'Resident')

df["Housing AC"] = df["Housing AC"].str.replace('with parents', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('With parents', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('off-campus, Parents house', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('at home', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('home', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('I lived parents', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('Off-campus parents', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('I lived resident', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('I lived Resident', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace('Local Resident prior', 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace("Crashed at friends' couches", 'Resident')
df["Housing AC"] = df["Housing AC"].str.replace("Same Resident", 'Resident')

# df["Housing AC"] = df["Housing AC"].str.replace('Off-campus Resident', 'House')
# df["Housing AC"] = df["Housing AC"].str.replace('Home', 'House')
# df["Housing BC"] = df["Housing BC"].str.replace('Off-campus Resident', 'House')
# df["Housing BC"] = df["Housing BC"].str.replace('Home', 'House')
# df["Housing AC"] = df["Housing AC"].str.replace("Off campus - House(Not greek) ", 'House')
# df["Housing BC"] = df["Housing BC"].str.replace("Off campus - House(Not greek) ", 'House')

comparable_students = df[df['UCR BC'] == "Yes"]
comparable_students.head()
# Out:
#             Timestamp  Gender Ethnicity Academic Year  \
# 0  1/28/2021 10:53:46  Female     White     Sophomore
# 1  1/30/2021 12:38:43    Male     Asian     Sophomore
# 2  1/30/2021 12:41:25    Male     Asian     Sophomore
# 3  1/30/2021 12:46:31    Male     Asian     Sophomore
# 4  1/30/2021 12:51:38  Female     Asian     Sophomore
#
#                                          Major         GPA UCR BC Housing BC  \
# 0                                           CS   3.7 - 4.0    Yes  UCR Dorms
# 1  Computer Science with Business Applications  3.3 - 3.69    Yes  UCR Dorms
# 2                                         CSBA   3.7 - 4.0    Yes  UCR Dorms
# 3                             Computer Science   3.7 - 4.0    Yes  UCR Dorms
# 4                             Computer Science  3.3 - 3.69    Yes  UCR Dorms
#
#   Housing no $              Housing AC                       Learning
# 0    On-campus     On Campus Apartment  In-person (on-campus lecture)
# 1   Off-campus  Off - Campus Apartment  In-person (on-campus lecture)
# 2    On-campus     On Campus Apartment  In-person (on-campus lecture)
# 3    On-campus     On Campus Apartment  In-person (on-campus lecture)
# 4    On-campus     On Campus Apartment  In-person (on-campus lecture)

# %%
#Clean Data
import matplotlib.pyplot as plt
df.head(80)
#Diagram 1 - Gender vs Housing without financial burder
gender_housing = pd.crosstab(comparable_students["Gender"], comparable_students["Housing no $"])
gender_housing_plot = gender_housing.plot.bar(stacked=True, colormap='Set3', figsize=(6,6))
gender_housing_plot.set_facecolor('Black')

# %%
#Diagram 2 - academic year vs housing BC
academic_year_housingBC = pd.crosstab(comparable_students["Academic Year"], comparable_students["Housing BC"])
academic_year_housingBC_plot = academic_year_housingBC.plot.bar(colormap='Oranges',figsize=(6,6))
academic_year_housingBC_plot.set_facecolor('Black')

# %%
#Diagram 3 - academic year vs housing AC
academic_year_housingAC = pd.crosstab(comparable_students["Academic Year"], comparable_students["Housing no $"])
academic_year_housingAC_plot = academic_year_housingAC.plot.bar(colormap='Set3', figsize=(6,6))
academic_year_housingAC_plot.set_facecolor('Black')

# %%
#Diagram 4 - total count for housing
gender_housing = comparable_students.groupby("Housing BC")["Housing AC"].count()
gender_housing.plot(kind='pie', subplots=True, shadow = True,startangle=90,figsize=(13,10), colormap='YlGnBu')
# Out:
# array([<AxesSubplot:ylabel='Housing AC'>], dtype=object)

# %%
sophomore_comparable_students = comparable_students[comparable_students['Academic Year'] == "Sophomore"]
sophomore_comparable_students.head()
junior_comparable_students = comparable_students[comparable_students['Academic Year'] == "Junior"]
junior_comparable_students.head()
sophomore_junior_students = pd.concat([sophomore_comparable_students, junior_comparable_students])
#sophomore_junior_students.head(80)
crosstab_AC = pd.crosstab(sophomore_junior_students["Academic Year"], sophomore_junior_students["Housing AC"],
            normalize=True)
crosstab_AC
#P(Academic year|AC)
AC_counts = crosstab_AC.sum(axis=0)
Academic_year_given_AC = crosstab_AC.divide(AC_counts, axis=1)
Academic_year_given_AC
stacked_Academic_year_given_AC = Academic_year_given_AC.plot.bar(colormap='BrBG',figsize=(6,6))
stacked_Academic_year_given_AC.set_facecolor('Black')

# %%
#P(AC|Academic year)
AC_counts = crosstab_AC.sum(axis=1)
AC_given_academic_year = crosstab_AC.divide(AC_counts, axis=0)
AC_given_academic_year
stacked_AC_given_academic_year = AC_given_academic_year.plot.bar(colormap='BrBG',figsize=(6,6))
stacked_AC_given_academic_year.set_facecolor('Black')

# %%
crosstab_BC = pd.crosstab(sophomore_junior_students["Academic Year"], sophomore_junior_students["Housing BC"],
            normalize=True)
crosstab_BC
#P(Academic year|BC)
BC_counts = crosstab_BC.sum(axis=0)
Academic_year_given_BC = crosstab_BC.divide(BC_counts, axis=1)
Academic_year_given_BC
stacked_Academic_year_given_BC = Academic_year_given_BC.plot.bar(colormap='GnBu',figsize=(6,6))
stacked_Academic_year_given_BC.set_facecolor('Black')

# %%
#P(BC|Academic year)
BC_counts = crosstab_BC.sum(axis=1)
BC_given_academic_year = crosstab_BC.divide(BC_counts, axis=0)
BC_given_academic_year
stacked_BC_given_academic_year = BC_given_academic_year.plot.bar(colormap='GnBu',figsize=(6,6))
stacked_BC_given_academic_year.set_facecolor('Black')

# %% [markdown]
# I believe that due to the way covid was handled by school related housing and regular housing people may change where they want to live when they go back. When people had to leave many students were unable to get refunds or their deposit back from off campus residencies. Many places faced legal action and through the consequences of that I think that people may be more favorable towards on-campus housing. To get housing data from pre-covid and after covid I have decided to just look at sophomores and juniors, basically any students that will be there after covid went to Riverside before Covid.

# %%
sophomore_junior_students[['Housing BC','Housing AC']].describe()
# Out:
#        Housing BC           Housing AC
# count          51                   51
# unique          5                    5
# top     UCR Dorms  On Campus Apartment
# freq           34                   25

# %%
housing_change = sophomore_junior_students.groupby(["Housing BC","Housing AC"])["Academic Year"].count()
housing_change_plot = housing_change.plot.bar(stacked=True, color ='White')
housing_change_plot.set_facecolor('Black')

# %% [markdown]
# <font size="4">**Can you state any hypotheses or make any predictions? Which tests can you
# apply to verify your hypothesis?**</font>

# %% [markdown]
# Hypothisis: Gender highly impacts where people live especially among college students. I believe that women are more likely to choose housing that is closer to campus and may choose to live on campus more than off campus. To get housing data from pre-covid and after covid I have decided to just look at sophomores and juniors, basically any students that will be there after covid went to Riverside before Covid.
# <br>
# <br>Null Hypothesis: There is no relationship between gender and on campus vs off campus housing.

# %% [markdown]
# I decided to use chi square to determine how much gender really affect housing.

# %%
from scipy import stats
from scipy.stats import chi2_contingency
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.stats import pearsonr
from sklearn import preprocessing
import seaborn as sns

# %%
gender_housing = sophomore_junior_students.groupby(["Housing no $", "Gender"]).count()
gender_housing
print(gender_housing)
gender_housing_avg = pd.crosstab(sophomore_junior_students["Housing no $"], sophomore_junior_students["Gender"],
            normalize=True)
gender_housing_avg.plot.bar(stacked=True, colormap='RdYlBu')
gender_housing_avg
# This diagram displays the number of people who would live on-campus/off- campus depending on gender
# Out:
#                                           Timestamp  Ethnicity  Academic Year  \
# Housing no $ Gender
# Off-campus   Female                               3          3              3
#              Male                                 9          9              9
#              Prefer not to say                    2          2              2
#              Questioning/Non-binary(ish)          1          1              1
# On-campus    Female                               9          9              9
#              Male                                26         26             26
#
#                                           Major  GPA  UCR BC  Housing BC  \
# Housing no $ Gender
# Off-campus   Female                           3    3       3           3
#              Male                             9    9       9           9
#              Prefer not to say                2    2       2           2
#              Questioning/Non-binary(ish)      1    1       1           1
# On-campus    Female                           9    9       9           9
#              Male                            26   26      26          26
#
#                                           Housing AC  Learning
# Housing no $ Gender
# Off-campus   Female                                3         3
#              Male                                  9         9
#              Prefer not to say                     2         2
#              Questioning/Non-binary(ish)           1         1
# On-campus    Female                                9         9
#              Male                                 26        26
# Gender        Female  Male  Prefer not to say  Questioning/Non-binary(ish)
# Housing no $
# Off-campus      0.06  0.18               0.04                         0.02
# On-campus       0.18  0.52               0.00                         0.00

# %%
# Chi-Square Test
chi, p, dof, expected = chi2_contingency(gender_housing_avg) 
print(f'Chi-value : {chi}')
print(f'P-Value : {p}')
print(f'Degree of freedom : {dof}')
print('Expectation : ')
#print(expected)
expected = pd.DataFrame(
    expected,
    index=["Off-campus","On-campus"],
    columns=["Female","Male","Prefer not to say","Questtioning/Non-binary(ish)"])
expected
# Out:
# Chi-value : 0.1489795918367347
# P-Value : 0.9853721171526216
# Degree of freedom : 3
# Expectation :
#             Female  Male  Prefer not to say  Questtioning/Non-binary(ish)
# Off-campus   0.072  0.21              0.012                         0.006
# On-campus    0.168  0.49              0.028                         0.014
